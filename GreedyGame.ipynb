# %%
import pandas as pd
import numpy as np

# %%
data =  pd.read_pickle('ggevent.log')
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# c:\users\dell\envs\assign1\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#      82         try:
# ---> 83             return read_wrapper(lambda f: pkl.load(f))
#      84         except Exception:
#
# c:\users\dell\envs\assign1\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#      67         try:
# ---> 68             return func(f)
#      69         finally:
#
# c:\users\dell\envs\assign1\lib\site-packages\pandas\io\pickle.py in <lambda>(f)
#      82         try:
# ---> 83             return read_wrapper(lambda f: pkl.load(f))
#      84         except Exception:
#
# EOFError: Ran out of input
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# ...

# %%
pwd
# Out:
# 'C:\\Users\\dell\\assign1'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is EA32-CDFB
#
#  Directory of C:\Users\dell\assign1
#
# 05/15/2017  10:03 PM    <DIR>          .
# 05/15/2017  10:03 PM    <DIR>          ..
# 05/15/2017  09:44 PM    <DIR>          .ipynb_checkpoints
# 05/11/2016  12:36 AM        43,089,181 ggevent.log
# 05/15/2017  10:03 PM             1,802 GreedyGame-Rough.ipynb
# 05/15/2017  09:21 PM    <DIR>          Include
# 05/15/2017  09:31 PM    <DIR>          Lib
# 05/15/2017  09:32 PM                60 pip-selfcheck.json
# 05/15/2017  09:32 PM    <DIR>          Scripts
# 05/15/2017  09:31 PM    <DIR>          tcl
#                3 File(s)     43,091,043 bytes
#                7 Dir(s)  23,375,265,792 bytes free

# %%
data
# Out:
#        {"headers": {"ai5": "8fa683e59c02c04cb781ac689686db07"   "debug": null  \
# 0       {"headers": {"ai5": "335644267c1d5f04eaea7bc6f...       "debug": null
# 1       {"headers": {"ai5": "ca3071aad676bc963795a2b09...       "debug": null
# 2       {"headers": {"ai5": "17412dec7d3d02c9b0b1c3d1c...       "debug": null
# 3       {"headers": {"ai5": "f81167c854f1a0c86cab6188f...       "debug": null
# 4       {"headers": {"ai5": "17412dec7d3d02c9b0b1c3d1c...       "debug": null
# 5       {"headers": {"ai5": "a2659df45c8d05f326225fa5b...       "debug": null
# 6       {"headers": {"ai5": "b8bbef76f8dfee2fe190a283c...       "debug": null
# 7       {"headers": {"ai5": "e8ebfc3f39512eda3aa0702b1...       "debug": null
# 8       {"headers": {"ai5": "988e4873861347113519fbee6...       "debug": null
# 9       {"headers": {"ai5": "583361d66ad8b0827cd08d3a5...       "debug": null
# 10      {"headers": {"ai5": "d775dbe1ca0e2610ae5505e7f...       "debug": null
# ...

# %%
data
# Out:
#         {"headers":  {"ai5":  8fa683e59c02c04cb781ac689686db07,  debug:  \
# 0       {"headers":  {"ai5":  335644267c1d5f04eaea7bc6f51b1861,  debug:
# 1       {"headers":  {"ai5":  ca3071aad676bc963795a2b09635cdf0,  debug:
# 2       {"headers":  {"ai5":  17412dec7d3d02c9b0b1c3d1c3571c5c,  debug:
# 3       {"headers":  {"ai5":  f81167c854f1a0c86cab6188f9995824,  debug:
# 4       {"headers":  {"ai5":  17412dec7d3d02c9b0b1c3d1c3571c5c,  debug:
# 5       {"headers":  {"ai5":  a2659df45c8d05f326225fa5b1063ac9,  debug:
# 6       {"headers":  {"ai5":  b8bbef76f8dfee2fe190a283cd5a19a7,  debug:
# 7       {"headers":  {"ai5":  e8ebfc3f39512eda3aa0702b13ffed63,  debug:
# 8       {"headers":  {"ai5":  988e4873861347113519fbee6dd1c3b0,  debug:
# 9       {"headers":  {"ai5":  583361d66ad8b0827cd08d3a5d64af89,  debug:
# 10      {"headers":  {"ai5":  d775dbe1ca0e2610ae5505e7f489ece0,  debug:
# 11      {"headers":  {"ai5":  ed278fbc0dc987010e0262260cf39e16,  debug:
# ...

# %%
data
# Out:
#                                                                                                                                                                                  ai5  \
# {"headers": {"ai5": 8fa683e59c02c04cb781ac689686db07, debug: null, random: null,                             sdkv: 7.6},   post: {"event": ggstart, ts: 1462759195259}, params:  {},
#                     335644267c1d5f04eaea7bc6f51b1861, debug: null, random: null,                             sdkv: 7.6},   post: {"event": ggstart, ts: 1462759189745}, params:  {},
#                     ca3071aad676bc963795a2b09635cdf0, debug: null, random: null,                             sdkv: 7.6},   post: {"event": ggstop,  ts: 1462768152242}, params:  {},
#                     17412dec7d3d02c9b0b1c3d1c3571c5c, debug: null, random: null,                             sdkv: 7.5.1}, post: {"event": ggstop,  ts: 1462759193807}, params:  {},
# ...

# %%
data
# Out:
#                                                                                                                                ai5  \
# {"headers": {"ai5": "8fa683e59c02c04cb781ac6896...  "debug": null  "random": null                                   "sdkv": "7.6"}
# {"headers": {"ai5": "335644267c1d5f04eaea7bc6f5...  "debug": null  "random": null                                   "sdkv": "7.6"}
# {"headers": {"ai5": "ca3071aad676bc963795a2b096...  "debug": null  "random": null                                   "sdkv": "7.6"}
# {"headers": {"ai5": "17412dec7d3d02c9b0b1c3d1c3...  "debug": null  "random": null                                 "sdkv": "7.5.1"}
# {"headers": {"ai5": "f81167c854f1a0c86cab6188f9...  "debug": null  "random": null                                   "sdkv": "7.6"}
# {"headers": {"ai5": "17412dec7d3d02c9b0b1c3d1c3...  "debug": null  "random": null                                 "sdkv": "7.5.1"}
# ...

# %%
data = open('ggevent.log','r')

# %%
data.readline()
# Out:
# ''

# %%
data.readlines()
# Out:
# []

# %%
data
# Out:
# <_io.TextIOWrapper name='ggevent.log' mode='r' encoding='cp1252'>

# %%
data
# Out:
# <_io.TextIOWrapper name='ggevent.log' mode='r' encoding='cp1252'>

# %%
with open('ggevent.log') as f:
    f = f.readlines()

# %%
f
# Out:
# ['{"headers": {"ai5": "8fa683e59c02c04cb781ac689686db07", "debug": null, "random": null, "sdkv": "7.6"}, "post": {"event": "ggstart", "ts": "1462759195259"}, "params": {}, "bottle": {"timestamp": "2016-05-09 02:00:00.004906", "game_id": "55107008"}}\n',
#  '{"headers": {"ai5": "335644267c1d5f04eaea7bc6f51b1861", "debug": null, "random": null, "sdkv": "7.6"}, "post": {"event": "ggstart", "ts": "1462759189745"}, "params": {}, "bottle": {"timestamp": "2016-05-09 02:00:00.033775", "game_id": "55107008"}}\n',
#  '{"headers": {"ai5": "ca3071aad676bc963795a2b09635cdf0", "debug": null, "random": null, "sdkv": "7.6"}, "post": {"event": "ggstop", "ts": "1462768152242"}, "params": {}, "bottle": {"timestamp": "2016-05-09 02:00:00.036721", "game_id": "55107008"}}\n',
# ...

# %%
type(f)
# Out:
# list

# %%
len(f
   )
# Out:
# 171721

# %%
n= len(f)

# %%
for i in range(0,n):
    print f[i]
# Out:
#   File "<ipython-input-47-3b163dec6d1a>", line 2
#     print f[i]
#           ^
# SyntaxError: Missing parentheses in call to 'print'
